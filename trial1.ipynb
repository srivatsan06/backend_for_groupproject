# %%
pip list
# Out:
# Package                      Version
# ---------------------------- --------------
# absl-py                      2.3.0
# anyio                        4.9.0
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    3.0.0
# astunparse                   1.6.3
# async-lru                    2.0.5
# attrs                        25.3.0
# babel                        2.17.0
# beautifulsoup4               4.13.4
# bleach                       6.2.0
# blinker                      1.9.0
# cachetools                   5.5.2
# certifi                      2025.4.26
# cffi                         1.17.1
# charset-normalizer           3.4.2
# click                        8.3.1
# colorama                     0.4.6
# comm                         0.2.2
# contourpy                    1.3.2
# cycler                       0.12.1
# debugpy                      1.8.14
# decorator                    5.2.1
# ...

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# False

# %%
import tensorflow as tf

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import sqlite3

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",       # MySQL server host
    database="new",         # database name
    user="warlord",            # MySQL username
    password="Warlord@200206"  # MySQL password
)

cursor = conn.cursor()

# %%
cursor.execute("SELECT * FROM hi;")
for i in cursor:
    print(i)
# Out:
# (5, 'warlord')

# %%
cursor.execute("SELECT * FROM hi;")
col_names = [desc[0] for desc in cursor.description]
rows = cursor.fetchall()

# Print header
print(" | ".join(col_names))
print("-" * len("   ".join(col_names)))

# Print rows aligned
for row in rows:
    print("        |     ".join(str(x) for x in row))
# Out:
# student_id | student_name
# -------------------------
# 5        |     warlord

# %%
cursor.execute("""
ALTER TABLE hi
ADD COLUMN `Weekly attendance` FLOAT,
ADD COLUMN `Submission deadlines` DATE,
ADD COLUMN `stress levels` INT CHECK (`stress levels` BETWEEN 1 AND 5),
ADD COLUMN `hours slept` FLOAT;
""")

# %%
cursor.execute("""
INSERT INTO hi
(`student_id`, `student_name`, `Weekly attendance`, `Submission deadlines`, `stress levels`, `hours slept`)
VALUES (%s, %s, %s, %s, %s, %s);
""", (2, 'vatsan', 95, '2025-12-05', 5, 5.3))

# %%
cursor.execute("""
UPDATE hi
SET `Weekly attendance` = %s, 
    `Submission deadlines` = %s, 
    `stress levels`=%s, 
    `hours slept`=%s
WHERE student_id = %s;""", 
(78, '2025-12-07', 3, 4.8,5))

# %%
cursor.execute("SELECT * FROM hi;")
col_names = [desc[0] for desc in cursor.description]
rows = cursor.fetchall()

# Print header
print(" | ".join(col_names))
print("-" * len("   ".join(col_names)))

# Print rows aligned
for row in rows:
    print("        |     ".join(str(x) for x in row))
# Out:
# student_id | student_name | Weekly attendance | Submission deadlines | stress levels | hours slept
# --------------------------------------------------------------------------------------------------
# 2        |     vatsan        |     95.0        |     2025-12-05        |     5        |     5.3
# 5        |     warlord        |     78.0        |     2025-12-07        |     3        |     4.8

# %%
conn.commit()

# %%
cursor.execute('SELECT "stress levels" FROM trial;')

# %%
for i in cursor:
    print(i[0])
# Out:
# 4
# 5
